# %%
# !pip install numpy
# !pip install matplotlib
# !pip install opencv-python
# Out:
# Requirement already satisfied: numpy in C:\Users\aditi\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (2.5.3)
# Requirement already satisfied: matplotlib in C:\Users\aditi\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (3.11.2)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\aditi\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (1.4.0)
# Requirement already satisfied: cycler>=0.10 in C:\Users\aditi\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.28.2 in C:\Users\aditi\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (4.66.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\aditi\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (1.5.1)
# Requirement already satisfied: numpy>=1.25 in C:\Users\aditi\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (2.5.3)
# Requirement already satisfied: packaging>=20.0 in C:\Users\aditi\AppData\Roaming\Python\Python314\site-packages (from matplotlib) (26.3)
# Requirement already satisfied: pillow>=9 in C:\Users\aditi\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in C:\Users\aditi\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (3.3.3)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\aditi\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in C:\Users\aditi\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: opencv-python in C:\Users\aditi\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (5.0.0.93)
# Requirement already satisfied: numpy>=2 in C:\Users\aditi\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from opencv-python) (2.5.3)

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread("images.jpeg")

# %%
print(type(img))
# Out:
# <class 'numpy.ndarray'>

# %%
cv2.imshow("bootcamp",img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
print(img.shape)
# Out:
# (619, 495, 3)

# %%
img_resize = cv2.resize(img,(203,300))

# %%
cv2.imshow("manya",img_resize)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
print(img_resize.shape)
# Out:
# (300, 203, 3)

# %%
img_flip = cv2.flip(img,1)

# %%
cv2.imshow("flipped Image",img_flip)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img_crop = img[100:300,200:500]

# %%
cv2.imshow("Cropped Image",img_crop)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
cv2.imwrite(r"croppedImg16.jpg",img_crop)
# Out:
# True

# %%
3+5
# Out:
# 8
