# %%
import cv2
import numpy as np
import matplotlib as plt

# %%
img=cv2.imread("photo.jpg")
print(type(img))
# Out:
# <class 'numpy.ndarray'>

# %%
print(img.shape)
# Out:
# (1024, 1024, 3)

# %%
import matplotlib.pyplot as plt

plt.imshow(img)
plt.axis("off")
plt.show()
