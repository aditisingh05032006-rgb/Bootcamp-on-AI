# %%
import sys
# !{sys.executable} -m pip install nltk wordcloud matplotlib
# Out:
# Collecting nltk
#   Using cached nltk-3.10.3-py3-none-any.whl.metadata (3.2 kB)
# Collecting wordcloud
#   Downloading wordcloud-1.9.6-cp314-cp314-win_amd64.whl.metadata (3.5 kB)
# Requirement already satisfied: matplotlib in c:\Users\aditi\AppData\Local\Programs\Python\Python314\Lib\site-packages (3.11.2)
# Collecting defusedxml (from nltk)
#   Using cached defusedxml-0.7.1-py2.py3-none-any.whl.metadata (32 kB)
# Collecting click (from nltk)
#   Using cached click-8.5.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting joblib (from nltk)
#   Using cached joblib-1.6.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting regex>=2021.8.3 (from nltk)
#   Using cached regex-2026.9.10-cp314-cp314-win_amd64.whl.metadata (41 kB)
# Collecting tqdm (from nltk)
#   Using cached tqdm-4.70.1-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: numpy>=1.19.3 in c:\Users\aditi\AppData\Local\Programs\Python\Python314\Lib\site-packages (from wordcloud) (2.5.3)
# Requirement already satisfied: pillow in c:\Users\aditi\AppData\Local\Programs\Python\Python314\Lib\site-packages (from wordcloud) (12.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\Users\aditi\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (1.4.0)
# Requirement already satisfied: cycler>=0.10 in c:\Users\aditi\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.28.2 in c:\Users\aditi\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (4.66.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\Users\aditi\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (1.5.1)
# Requirement already satisfied: packaging>=20.0 in C:\Users\aditi\AppData\Roaming\Python\Python314\site-packages (from matplotlib) (26.3)
# Requirement already satisfied: pyparsing>=3 in c:\Users\aditi\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (3.3.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\Users\aditi\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\Users\aditi\AppData\Local\Programs\Python\Python314\Lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Collecting cloudpickle>=3.0 (from joblib->nltk)
#   Using cached cloudpickle-3.1.2-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: colorama in C:\Users\aditi\AppData\Roaming\Python\Python314\site-packages (from tqdm->nltk) (0.4.6)
# Using cached nltk-3.10.3-py3-none-any.whl (1.8 MB)
# Downloading wordcloud-1.9.6-cp314-cp314-win_amd64.whl (308 kB)
# Using cached regex-2026.9.10-cp314-cp314-win_amd64.whl (281 kB)
# Using cached click-8.5.0-py3-none-any.whl (125 kB)
# Using cached defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Using cached joblib-1.6.0-py3-none-any.whl (306 kB)
# Using cached cloudpickle-3.1.2-py3-none-any.whl (22 kB)
# Using cached tqdm-4.70.1-py3-none-any.whl (80 kB)
# Installing collected packages: tqdm, regex, defusedxml, cloudpickle, click, joblib, wordcloud, nltk
#
#    ---------------------------------------- 0/8 [tqdm]
#    ---------------------------------------- 0/8 [tqdm]
#    ---------------------------------------- 0/8 [tqdm]
#    ---------------------------------------- 0/8 [tqdm]
#    ---------------------------------------- 0/8 [tqdm]
#    ---------------------------------------- 0/8 [tqdm]
#    ----- ---------------------------------- 1/8 [regex]
#    ----- ---------------------------------- 1/8 [regex]
#    ---------- ----------------------------- 2/8 [defusedxml]
#    --------------- ------------------------ 3/8 [cloudpickle]
#    -------------------- ------------------- 4/8 [click]
#    -------------------- ------------------- 4/8 [click]
#    -------------------- ------------------- 4/8 [click]
#    ------------------------- -------------- 5/8 [joblib]
#    ------------------------- -------------- 5/8 [joblib]
#    ------------------------- -------------- 5/8 [joblib]
#    ------------------------- -------------- 5/8 [joblib]
#    ------------------------- -------------- 5/8 [joblib]
#    ------------------------- -------------- 5/8 [joblib]
#    ------------------------- -------------- 5/8 [joblib]
#    ------------------------- -------------- 5/8 [joblib]
#    ------------------------- -------------- 5/8 [joblib]
#    ------------------------- -------------- 5/8 [joblib]
#    ------------------------- -------------- 5/8 [joblib]
#    ------------------------- -------------- 5/8 [joblib]
#    ------------------------- -------------- 5/8 [joblib]
#    ------------------------- -------------- 5/8 [joblib]
#    ------------------------- -------------- 5/8 [joblib]
#    ------------------------------ --------- 6/8 [wordcloud]
#    ------------------------------ --------- 6/8 [wordcloud]
#    ----------------------------------- ---- 7/8 [nltk]
#    ----------------------------------- ---- 7/8 [nltk]
#    ----------------------------------- ---- 7/8 [nltk]
#    ----------------------------------- ---- 7/8 [nltk]
#    ----------------------------------- ---- 7/8 [nltk]
#    ----------------------------------- ---- 7/8 [nltk]
#    ----------------------------------- ---- 7/8 [nltk]
#    ----------------------------------- ---- 7/8 [nltk]
#    ----------------------------------- ---- 7/8 [nltk]
#    ----------------------------------- ---- 7/8 [nltk]
#    ----------------------------------- ---- 7/8 [nltk]
#    ----------------------------------- ---- 7/8 [nltk]
#    ----------------------------------- ---- 7/8 [nltk]
#    ----------------------------------- ---- 7/8 [nltk]
#    ----------------------------------- ---- 7/8 [nltk]
#    ----------------------------------- ---- 7/8 [nltk]
#    ----------------------------------- ---- 7/8 [nltk]
#    ----------------------------------- ---- 7/8 [nltk]
#    ----------------------------------- ---- 7/8 [nltk]
#    ----------------------------------- ---- 7/8 [nltk]
#    ----------------------------------- ---- 7/8 [nltk]
#    ----------------------------------- ---- 7/8 [nltk]
#    ----------------------------------- ---- 7/8 [nltk]
#    ----------------------------------- ---- 7/8 [nltk]
#    ----------------------------------- ---- 7/8 [nltk]
#    ----------------------------------- ---- 7/8 [nltk]
#    ----------------------------------- ---- 7/8 [nltk]
#    ----------------------------------- ---- 7/8 [nltk]
#    ----------------------------------- ---- 7/8 [nltk]
#    ----------------------------------- ---- 7/8 [nltk]
#    ----------------------------------- ---- 7/8 [nltk]
#    ----------------------------------- ---- 7/8 [nltk]
#    ----------------------------------- ---- 7/8 [nltk]
#    ----------------------------------- ---- 7/8 [nltk]
#    ----------------------------------- ---- 7/8 [nltk]
#    ----------------------------------- ---- 7/8 [nltk]
#    ----------------------------------- ---- 7/8 [nltk]
#    ----------------------------------- ---- 7/8 [nltk]
#    ----------------------------------- ---- 7/8 [nltk]
#    ----------------------------------- ---- 7/8 [nltk]
#    ----------------------------------- ---- 7/8 [nltk]
#    ----------------------------------- ---- 7/8 [nltk]
#    ----------------------------------- ---- 7/8 [nltk]
#    ----------------------------------- ---- 7/8 [nltk]
#    ----------------------------------- ---- 7/8 [nltk]
#    ----------------------------------- ---- 7/8 [nltk]
#    ----------------------------------- ---- 7/8 [nltk]
#    ----------------------------------- ---- 7/8 [nltk]
#    ----------------------------------- ---- 7/8 [nltk]
#    ----------------------------------- ---- 7/8 [nltk]
#    ----------------------------------- ---- 7/8 [nltk]
#    ----------------------------------- ---- 7/8 [nltk]
#    ----------------------------------- ---- 7/8 [nltk]
#    ----------------------------------- ---- 7/8 [nltk]
#    ----------------------------------- ---- 7/8 [nltk]
#    ----------------------------------- ---- 7/8 [nltk]
#    ----------------------------------- ---- 7/8 [nltk]
#    ----------------------------------- ---- 7/8 [nltk]
#    ----------------------------------- ---- 7/8 [nltk]
#    ----------------------------------- ---- 7/8 [nltk]
#    ----------------------------------- ---- 7/8 [nltk]
#    ----------------------------------- ---- 7/8 [nltk]
#    ----------------------------------- ---- 7/8 [nltk]
#    ----------------------------------- ---- 7/8 [nltk]
#    ----------------------------------- ---- 7/8 [nltk]
#    ----------------------------------- ---- 7/8 [nltk]
#    ----------------------------------- ---- 7/8 [nltk]
#    ----------------------------------- ---- 7/8 [nltk]
#    ----------------------------------- ---- 7/8 [nltk]
#    ----------------------------------- ---- 7/8 [nltk]
#    ----------------------------------- ---- 7/8 [nltk]
#    ----------------------------------- ---- 7/8 [nltk]
#    ----------------------------------- ---- 7/8 [nltk]
#    ----------------------------------- ---- 7/8 [nltk]
#    ----------------------------------- ---- 7/8 [nltk]
#    ----------------------------------- ---- 7/8 [nltk]
#    ----------------------------------- ---- 7/8 [nltk]
#    ----------------------------------- ---- 7/8 [nltk]
#    ----------------------------------- ---- 7/8 [nltk]
#    ----------------------------------- ---- 7/8 [nltk]
#    ----------------------------------- ---- 7/8 [nltk]
#    ---------------------------------------- 8/8 [nltk]
#
# Successfully installed click-8.5.0 cloudpickle-3.1.2 defusedxml-0.7.1 joblib-1.6.0 nltk-3.10.3 regex-2026.9.10 tqdm-4.70.1 wordcloud-1.9.6
# WARNING: Cache entry deserialization failed, entry ignored
# WARNING: Cache entry deserialization failed, entry ignored
# WARNING: Cache entry deserialization failed, entry ignored
# WARNING: Cache entry deserialization failed, entry ignored
# WARNING: Cache entry deserialization failed, entry ignored
# WARNING: Cache entry deserialization failed, entry ignored
# WARNING: Cache entry deserialization failed, entry ignored
#   WARNING: The script tqdm.exe is installed in 'c:\Users\aditi\AppData\Local\Programs\Python\Python314\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script wordcloud_cli.exe is installed in 'c:\Users\aditi\AppData\Local\Programs\Python\Python314\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script nltk.exe is installed in 'c:\Users\aditi\AppData\Local\Programs\Python\Python314\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip is available: 26.1.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\aditi\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\aditi\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# True

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from collections import Counter

# Ensure necessary NLTK data is downloaded
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\aditi\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\aditi\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
text = """
Photography is an art that captures the beauty of moments in time. Whether it's a landscape, portrait, or an event,
a photograph can tell a powerful story. Great photographers use their cameras as tools to convey emotions, memories,
and scenes from everyday life. The composition, lighting, and timing of a shot are key elements in creating stunning photos.
Photography also plays a significant role in digital media, social media, and marketing. The evolution of camera technology,
from film cameras to digital cameras, has revolutionized how we capture images. Every photograph is a unique creation,
reflecting the photographer's perspective and artistic style. I like Photography Photography Photography Photography Photography Photography Photography Photography .
"""
print(text)
# Out:
# Photography is an art that captures the beauty of moments in time. Whether it's a landscape, portrait, or an event,
# a photograph can tell a powerful story. Great photographers use their cameras as tools to convey emotions, memories,
# and scenes from everyday life. The composition, lighting, and timing of a shot are key elements in creating stunning photos.
# Photography also plays a significant role in digital media, social media, and marketing. The evolution of camera technology,
# from film cameras to digital cameras, has revolutionized how we capture images. Every photograph is a unique creation,
# reflecting the photographer's perspective and artistic style. I like Photography Photography Photography Photography Photography Photography Photography Photography .

# %%
words = word_tokenize(text.lower())  # Convert to lowercase for uniformity
print(words)
# Out:
# ['photography', 'is', 'an', 'art', 'that', 'captures', 'the', 'beauty', 'of', 'moments', 'in', 'time', '.', 'whether', 'it', "'s", 'a', 'landscape', ',', 'portrait', ',', 'or', 'an', 'event', ',', 'a', 'photograph', 'can', 'tell', 'a', 'powerful', 'story', '.', 'great', 'photographers', 'use', 'their', 'cameras', 'as', 'tools', 'to', 'convey', 'emotions', ',', 'memories', ',', 'and', 'scenes', 'from', 'everyday', 'life', '.', 'the', 'composition', ',', 'lighting', ',', 'and', 'timing', 'of', 'a', 'shot', 'are', 'key', 'elements', 'in', 'creating', 'stunning', 'photos', '.', 'photography', 'also', 'plays', 'a', 'significant', 'role', 'in', 'digital', 'media', ',', 'social', 'media', ',', 'and', 'marketing', '.', 'the', 'evolution', 'of', 'camera', 'technology', ',', 'from', 'film', 'cameras', 'to', 'digital', 'cameras', ',', 'has', 'revolutionized', 'how', 'we', 'capture', 'images', '.', 'every', 'photograph', 'is', 'a', 'unique', 'creation', ',', 'reflecting', 'the', 'photographer', "'s", 'perspective', 'and', 'artistic', 'style', '.', 'i', 'like', 'photography', 'photography', 'photography', 'photography', 'photography', 'photography', 'photography', 'photography', '.']

# %%
stop_words = set(stopwords.words('english'))
filtered_words = [word for word in words if word.isalpha() and word not in stop_words]
# The general syntax for a list comprehension is: [expression for item in iterable if condition]
print(filtered_words)
# Out:
# ['photography', 'art', 'captures', 'beauty', 'moments', 'time', 'whether', 'landscape', 'portrait', 'event', 'photograph', 'tell', 'powerful', 'story', 'great', 'photographers', 'use', 'cameras', 'tools', 'convey', 'emotions', 'memories', 'scenes', 'everyday', 'life', 'composition', 'lighting', 'timing', 'shot', 'key', 'elements', 'creating', 'stunning', 'photos', 'photography', 'also', 'plays', 'significant', 'role', 'digital', 'media', 'social', 'media', 'marketing', 'evolution', 'camera', 'technology', 'film', 'cameras', 'digital', 'cameras', 'revolutionized', 'capture', 'images', 'every', 'photograph', 'unique', 'creation', 'reflecting', 'photographer', 'perspective', 'artistic', 'style', 'like', 'photography', 'photography', 'photography', 'photography', 'photography', 'photography', 'photography', 'photography']

# %%
from collections import Counter

word_freq = Counter(words)  # replace `words` with whatever your list variable is called

wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(word_freq)

# %%
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')  # Hide axes
plt.show()
